# %% [markdown]
# # CSE-221710305047-SAI_D_VETUKURI

# %% [markdown]
# # Numerical Calculation of K-Nearest Neighbors:

# %% [markdown]
# Problem Statement:
# ![image.png](attachment:image.png)

# %% [markdown]
# Now the factory produces a new paper tissue with X1 value as 3 and X2 value as 7. What is the classification of this new tissue(Good or Bad).

# %% [markdown]
# If k=1 nearest neighbor, what would be the classification of new paper tissue<br>
#     1. Calculate the distance between the query instance(3,7) and all the training samples.
#     2. Sort the distance and determine nearest neighbor based on k
#     3. Gather the y category of nearest neighbor and that category becomes the predicted class of query instance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={'X1':[7,7,3,1],'X2':[7,4,4,4],'Y':["Bad","Bad","Good","Good"]}
data
# Out:
# {'X1': [7, 7, 3, 1], 'X2': [7, 4, 4, 4], 'Y': ['Bad', 'Bad', 'Good', 'Good']}

# %%
df=pd.DataFrame(data)
df
# Out:
#    X1  X2     Y
# 0   7   7   Bad
# 1   7   4   Bad
# 2   3   4  Good
# 3   1   4  Good

# %%
x=3
y=7

# %%
data1=data['X1']
data2=data['X2']
data1
# Out:
# [7, 7, 3, 1]

# %%
data2
# Out:
# [7, 4, 4, 4]

# %%
data3=[]
import math
for i in range(0,len(data1)):
    sq=(x-data1[i])**2 + (y-data2[i])**2
    data3.append(math.sqrt(sq))
data3
# Out:
# [4.0, 5.0, 3.0, 3.605551275463989]

# %%
df1=pd.DataFrame(data3,columns=['Distance'])
df1
# Out:
#    Distance
# 0  4.000000
# 1  5.000000
# 2  3.000000
# 3  3.605551

# %%
df2=pd.concat([df,df1],axis=1)
df2
# Out:
#    X1  X2     Y  Distance
# 0   7   7   Bad  4.000000
# 1   7   4   Bad  5.000000
# 2   3   4  Good  3.000000
# 3   1   4  Good  3.605551

# %%
df2.sort_values(by=['Distance'],inplace=True)

# %%
df2
# Out:
#    X1  X2     Y  Distance
# 2   3   4  Good  3.000000
# 3   1   4  Good  3.605551
# 0   7   7   Bad  4.000000
# 1   7   4   Bad  5.000000

# %%
df.append({'X1':3,'X2':7,'Y':"Good"},ignore_index=True)
# Out:
#    X1  X2     Y
# 0   7   7   Bad
# 1   7   4   Bad
# 2   3   4  Good
# 3   1   4  Good
# 4   3   7  Good

# %% [markdown]
# ###### When k=1 from (3,7) point <br>
# ###### Then (3,4) is the only point i.e., (3,4) is the nearest point for the (3,7) point <br>
# ###### (3,4) is classified as Good so , we will consider (3,7) also as Good  with k=1<br>

# %% [markdown]
# If k=3 nearest neighbor, what would be the classification of new paper tissue<br>
#     1. Calculate the distance between the query instance(3,7) and all the training samples.
#     2. Sort the distance and determine nearest neighbor based on k
#     3. Gather the y category of nearest neighbor and that category becomes the predicted class of query instance

# %%
data={'X1':[7,7,3,1],'X2':[7,4,4,4],'Y':["Bad","Bad","Good","Good"]}
data
# Out:
# {'X1': [7, 7, 3, 1], 'X2': [7, 4, 4, 4], 'Y': ['Bad', 'Bad', 'Good', 'Good']}

# %%
df=pd.DataFrame(data)
df
# Out:
#    X1  X2     Y
# 0   7   7   Bad
# 1   7   4   Bad
# 2   3   4  Good
# 3   1   4  Good

# %%
x=3
y=7

# %%
data1=data['X1']
data2=data['X2']
data1
# Out:
# [7, 7, 3, 1]

# %%
data2
# Out:
# [7, 4, 4, 4]

# %%
data3=[]
import math
for i in range(0,len(data1)):
    sq=(x-data1[i])**2 + (y-data2[i])**2
    data3.append(math.sqrt(sq))
data3
# Out:
# [4.0, 5.0, 3.0, 3.605551275463989]

# %%
df1=pd.DataFrame(data3,columns=['Distance'])
df1
# Out:
#    Distance
# 0  4.000000
# 1  5.000000
# 2  3.000000
# 3  3.605551

# %%
df2=pd.concat([df,df1],axis=1)
df2
# Out:
#    X1  X2     Y  Distance
# 0   7   7   Bad  4.000000
# 1   7   4   Bad  5.000000
# 2   3   4  Good  3.000000
# 3   1   4  Good  3.605551

# %%
df2.sort_values(by=['Distance'],inplace=True)
df2
# Out:
#    X1  X2     Y  Distance
# 2   3   4  Good  3.000000
# 3   1   4  Good  3.605551
# 0   7   7   Bad  4.000000
# 1   7   4   Bad  5.000000

# %%
df.append({'X1':3,'X2':7,'Y':"Good"},ignore_index=True)
# Out:
#    X1  X2     Y
# 0   7   7   Bad
# 1   7   4   Bad
# 2   3   4  Good
# 3   1   4  Good
# 4   3   7  Good

# %% [markdown]
# ###### When k=3 from (3,7) point<br>
# ###### Then (3,4),(1,4) and (7,7) are the point nearest to (3,7)<br>
# ###### (3,4) is classified as Good<br>
# ###### (1,4) is classified as Good<br>
# ###### (7,7) is classified as Bad<br>
# ###### Here the majority of Y for the above points is Good so, the new point (3,7) is classified as Good with k=3<br>
